# %% [markdown]
# ### 분할표 (이변량) 카이제곱 검정

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. 예시 #1.

# %% [markdown]
# 다음은 미국에서 592명 성인 남녀의 눈색과 머리칼 색을 정리해 놓은 분할표이다. <br>
# 개개 행은 머리칼 색, 개개 열은 눈색을 나타낸다. <br>
# 분할표카이제곱검정 (독립성 검정)을 실시해 보자.

# %%
data_eye = {'Brown': [68,119,26,7], 'Blue':[20,84,17,94], 'Hazel':[15,54,14,10], 'Green':[5, 29, 14,16]}
data = pd.DataFrame(data_eye,index=['Black','Brown','Red','Blonde'])
data
# Out:
#         Brown  Blue  Hazel  Green
# Black      68    20     15      5
# Brown     119    84     54     29
# Red        26    17     14     14
# Blonde      7    94     10     16

# %%
data.plot.bar(stacked=True,color=['brown','blue','yellow','green'])
plt.show()

# %%
# 검정통계량, p-값, 자유도, 기대도수.
stat, p_val, df, expected = st.chi2_contingency(data)
print("p_value : {}".format(np.round(p_val,3)))
# Out:
# p_value : 0.0

# %% [markdown]
# #### 2. 예시 #2.

# %% [markdown]
# 다음은 타이타닉호의 객실등급 변수와 생존여부 변수 사이의 분할표이다. <br>
# 이 두 변수 사이의 독립성을 검정해 보자.

# %%
data_survived = {'Yes':[122, 167, 528, 673], 'No':[203,118,178,212]}
data = pd.DataFrame(data_survived,index=['1st','2nd','3rd','Crew'])
data
# Out:
#       Yes   No
# 1st   122  203
# 2nd   167  118
# 3rd   528  178
# Crew  673  212

# %%
data.plot.bar(stacked=True, color=['blue','red'])
plt.show()

# %%
# 검정통계량, p-값, 자유도, 기대도수.
stat, p_val, df, expected = st.chi2_contingency(data)
print("p_value : {}".format(np.round(p_val,3)))
# Out:
# p_value : 0.0
