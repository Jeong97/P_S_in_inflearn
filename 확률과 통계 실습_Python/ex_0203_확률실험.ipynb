# %% [markdown]
# ### 확률실험

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. 표준정규 확률변수를 관찰하여 히스토그램으로 시각화 해본다.

# %%
my_list = []
for _ in range(100000):
    z = np.random.randn()                       # 표준정규 랜덤넘버.
    my_list.append(z)

# %%
plt.hist(my_list, bins=100, color='green', alpha=0.3, density=True)
plt.show()

# %%
# NumPy 배열로 변환.
Z = np.array(my_list)

# %%
# 평균 확인.
np.round(Z.mean(),2)
# Out:
# 0.0

# %%
# 표준편차 확인.
np.round(Z.std(),2)
# Out:
# 1.01

# %% [markdown]
# #### 2. 표준정규 확률변수를 임의의 정규 확률변수로 변환시키고 시각화 해본다.

# %%
mu = 10                # 임의의 평균.
sigma = 3              # 임의의 표준편차.
X = sigma*Z + mu       # 변환.

# %%
plt.hist(Z, bins=100, color='green', alpha=0.3, density=True)
plt.hist(X, bins=100, color='red', alpha=0.3, density=True)
plt.show()

# %% [markdown]
# #### 3. 카이제곱 확률변수 샘플링과 시각화.

# %%
my_list = []
for _ in range(100000):
    Z1 = np.random.randn()                      # 표준정규 랜덤넘버.
    Z2 = np.random.randn()                      # 표준정규 랜덤넘버.
    Z3 = np.random.randn()                      # 표준정규 랜덤넘버.
    Z4 = np.random.randn()                      # 표준정규 랜덤넘버.
    Z5 = np.random.randn()                      # 표준정규 랜덤넘버.
    Q = Z1**2 + Z2**2 + Z3**2 + Z4**2 +Z5**2   
    my_list.append(Q)

# %%
plt.hist(my_list, bins=200, color='red', alpha=0.3, density=True)
plt.xlim([0,10])
plt.ylim([0,1])
plt.show()
