# %% [markdown]
# ### 명목형 변수와 더미변수

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab.files import upload
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %% [markdown]
# #### 1. 데이터셋을 읽어 온다.

# %%
# df = pd.read_csv('./data/data_studentlist_en.csv', header='infer')  # 로컬파일 읽어오기.

# %%
dict_data = upload()                                                  # Colab으로 파일 올리기.
df = pd.read_csv(io.BytesIO(dict_data['data_studentlist_en.csv']))    # Colab으로 올린 파일 읽어오기.
# Out:
#      <input type="file" id="files-1ba3c2de-8712-42d0-8cf3-b8dd2b0f10e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ba3c2de-8712-42d0-8cf3-b8dd2b0f10e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# height, weight, gender 변수를 사용할 예정이다.
df.head(5)
# Out:
#               name gender  age  grade absence bloodtype  height  weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %% [markdown]
# #### 2. 명목형 변수를 사용하지 않는 경우.
# <br>
# 수식: weight ~ height

# %%
# 선형회귀.
lm = LinearRegression()
X = df.height.values.reshape(-1,1)
Y = df.weight.values.reshape(-1,1)
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
rsq1 = lm.score(X,Y)
rmse1 = np.sqrt(mean_squared_error(Y, lm.predict(X)))

# %%
# 시각화.
# 회귀선을 gender별로 구분할 필요는 없다.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='black')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# #### 3. 명목형 변수를 사용하는 경우.
# <br>
# 수식: weight ~ height + gender

# %%
# 'gender'를 사용해서 더미변수를 만든다.
gender_dummy = pd.get_dummies(df.gender, drop_first=True, prefix='gender')
X = df[['height']].join(gender_dummy)
Y = df[['weight']]
X
# Out:
#     height  gender_M
# 0    165.3         1
# 1    170.1         0
# 2    175.0         1
# 3    182.1         1
# 4    168.0         0
# 5    162.0         0
# 6    155.2         0
# 7    176.9         0
# 8    178.5         1
# 9    176.1         1
# 10   167.1         1
# 11   180.0         1
# 12   162.2         1
# 13   176.1         0
# 14   158.2         0
# 15   168.6         1
# 16   169.2         1

# %%
# 선형회귀.
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
b2 = lm.coef_[0][1]
rsq2 = lm.score(X,Y)
rmse2 = np.sqrt(mean_squared_error(Y, lm.predict(X)))

# %%
# 시각화.
# 회귀선을 gender별로 구분한다.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='red')
plt.plot(x_grid, (b0 + b2) + b1*x_grid, linestyle='--',linewidth=1,color='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# #### 4. 상호작용하는 명목형 변수를 사용하는 경우.
# <br>
# 수식: weight ~ height + gender + height $\times$ gender

# %%
# 'gender'를 사용해서 더미변수를 만든다.
gender_dummy = pd.get_dummies(df.gender, drop_first=True, prefix='gender')
X = df[['height']].join(gender_dummy)
Y = df[['weight']]
X
# Out:
#     height  gender_M
# 0    165.3         1
# 1    170.1         0
# 2    175.0         1
# 3    182.1         1
# 4    168.0         0
# 5    162.0         0
# 6    155.2         0
# 7    176.9         0
# 8    178.5         1
# 9    176.1         1
# 10   167.1         1
# 11   180.0         1
# 12   162.2         1
# 13   176.1         0
# 14   158.2         0
# 15   168.6         1
# 16   169.2         1

# %%
# 상호작용 항을 만든다. 
X['height x gender_M'] = X['height']*X['gender_M']
X.head(5)
# Out:
#    height  gender_M  height x gender_M
# 0   165.3         1              165.3
# 1   170.1         0                0.0
# 2   175.0         1              175.0
# 3   182.1         1              182.1
# 4   168.0         0                0.0

# %%
# 선형회귀.
lm.fit(X,Y)
b0 = lm.intercept_[0]
b1 = lm.coef_[0][0]
b2 = lm.coef_[0][1]
b3 = lm.coef_[0][2]
rsq3 = lm.score(X,Y)
rmse3 = np.sqrt(mean_squared_error(Y, lm.predict(X)))

# %%
# 시각화.
# 회귀선을 gender별로 구분할 필요는 없다.
df_m = df[df.gender=='M']
df_f = df[df.gender=='F']
x_grid = np.linspace(155,190,10)
plt.scatter(x=df_m.height, y=df_m.weight, color='blue', alpha = 0.5)
plt.scatter(x=df_f.height, y=df_f.weight, color='red', alpha = 0.5)
plt.plot(x_grid, b0 + b1*x_grid, linestyle='--',linewidth=1,color='red')
plt.plot(x_grid, (b0 + b2) + (b1 + b3)*x_grid, linestyle='--',linewidth=1,color='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# #### 5. $R^2$와 RMSE 비교.

# %%
np.round([rsq1, rsq2, rsq3],3)
# Out:
# array([0.441, 0.762, 0.787])

# %%
np.round([rmse1, rmse2, rmse3],3)
# Out:
# array([8.595, 5.613, 5.307])

# %% [markdown]
# **주의: 상호작용하는 명목형 변수가 있을 때 $R^2$는 가장 크고, *RMSE*는 가장 작다.**
